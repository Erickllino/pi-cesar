# %%
import pandas as pd
import os

# %%
import os
print(os.getcwd())
# Out:
# /home/yienvee/Documents/PI-Cesar/ArtPrompt

# %%
HEx_PHI = pd.read_json('dataset/HEx-PHI/HEx_PHI_sub10.json', encoding='utf-8')

# %%
Vitc1 = pd.read_json('dataset/ViTC/vitc-l.json', encoding='utf-8')

# %%
Vitc2 = pd.read_json('dataset/ViTC/vitc-s.json', encoding='utf-8')

# %%
harmful_behaviors = pd.read_csv('dataset/harmful_behaviors_custom.csv', encoding='utf-8')

# %%
print("HEx_PHI:", HEx_PHI.shape)
print("ViTC-l:", Vitc1.shape)
print("ViTC-s:", Vitc2.shape)
print("Harmful Behaviors:", harmful_behaviors.shape)
# Out:
# HEx_PHI: (11, 2)
# ViTC-l: (8000, 4)
# ViTC-s: (8424, 4)
# Harmful Behaviors: (50, 5)

# %%
Vitc1
# Out:
#         id  text   font                                           art_text
# 0        0    GM   thin                    \n,---.        ,-.-.\n|  _. ...
# 1        1    BP   thin                    \n,---.        ,---.\n|---. ...
# 2        2    PX   thin                   \n,---.        .  ,\n|---'   ...
# 3        3    N7   thin                   \n,   .        ---.\n|\  |   ...
# 4        4    MZ   thin                    \n,-.-.        ,---,\n| | | ...
# ...    ...   ...    ...                                                ...
# 7995  7995  AKSU  basic   .d8b.      db   dD     .d8888.     db    db \...
# 7996  7996  8D50  basic  .d888b.     d8888b.       ooooo      .d88b.  \...
# 7997  7997  HGM3  basic  db   db      d888b      .88b  d88.     d8888b....
# 7998  7998  5NZU  basic    ooooo     d8b   db     d88888D     db    db ...
# 7999  7999  S95C  basic  .d8888.     .d888b.       ooooo      .o88b. \n...
#
# [8000 rows x 4 columns]

# %%
i = 7999
print(Vitc1['text'][i])
print(Vitc1['art_text'][i])
# Out:
# S95C
# .d8888.     .d888b.       ooooo      .o88b.
# 88'  YP     88' `8D      8P~~~~     d8P  Y8
# `8bo.       `V8o88'     dP          8P
#   `Y8b.        d8'      V8888b.     8b
# db   8D       d8'           `8D     Y8b  d8
# `8888Y'      d8'        88oobY'      `Y88P'
